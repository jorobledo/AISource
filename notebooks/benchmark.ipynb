# %% [markdown]
# # AISource benchmark template
#
# No model or dataset is included yet. Complete the checklist below before adding benchmark code.

# %% [markdown]
# ## Checklist
#
# - [ ] Dataset manifest completed
# - [ ] MCPL features and units agreed
# - [ ] Statistical weights defined
# - [ ] Train/validation/test split defined
# - [ ] Metrics defined
# - [ ] First model implemented
# - [ ] Benchmark runner implemented

# %%
from pathlib import Path

import yaml

root = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
config_path = root / 'configs' / 'benchmark.template.yaml'
config = yaml.safe_load(config_path.read_text())
config

# %% [markdown]
# ## Future sections
#
# 1. Load and inspect the MCPL dataset.
# 2. Train the selected model.
# 3. Generate neutron samples.
# 4. Calculate metrics.
# 5. Plot and compare results.
